# %%
import pandas as pd
import numpy as np

# %%
df1=pd.read_csv("car_resale_prices.csv")
df1.head()
# Out:
#    Unnamed: 0                     full_name resale_price registered_year  \
# 0           0  2017 Maruti Baleno 1.2 Alpha  ₹ 5.45 Lakh            2017
# 1           1            2018 Tata Hexa XTA    ₹ 10 Lakh            2018
# 2           2   2015 Maruti Swift Dzire VXI  ₹ 4.50 Lakh            2015
# 3           3   2015 Maruti Swift Dzire VXI  ₹ 4.50 Lakh            2015
# 4           4    2009 Hyundai i10 Magna 1.1  ₹ 1.60 Lakh            2009
#
#   engine_capacity              insurance transmission_type  kms_driven  \
# 0         1197 cc  Third Party insurance            Manual  40,000 Kms
# 1         2179 cc  Third Party insurance         Automatic  70,000 Kms
# 2         1197 cc  Third Party insurance            Manual  70,000 Kms
# 3         1197 cc  Third Party insurance            Manual  70,000 Kms
# 4         1086 cc  Third Party insurance            Manual  80,000 Kms
#
#      owner_type fuel_type  max_power  seats     mileage  body_type  city
# ...

# %%
df1.describe()
# Out:
#          Unnamed: 0         seats
# count  17446.000000  17436.000000
# mean    8722.500000      5.205494
# std     5036.370734      0.669321
# min        0.000000      2.000000
# 25%     4361.250000      5.000000
# 50%     8722.500000      5.000000
# 75%    13083.750000      5.000000
# max    17445.000000     14.000000

# %%
df1["full_name"].unique()
# Out:
# array(['2017 Maruti Baleno 1.2 Alpha', '2018 Tata Hexa XTA',
#        '2015 Maruti Swift Dzire VXI', ..., '2016 Toyota Camry 2.5 Hybrid',
#        '2016 Toyota Corolla Altis GL MT', '2017 Maruti Swift Dzire VDi'],
#       shape=(6923,), dtype=object)

# %%
df1["Brand"]= df1["full_name"].str.split().str[0]
df1.head()
# Out:
#    Unnamed: 0                     full_name resale_price registered_year  \
# 0           0  2017 Maruti Baleno 1.2 Alpha  ₹ 5.45 Lakh            2017
# 1           1            2018 Tata Hexa XTA    ₹ 10 Lakh            2018
# 2           2   2015 Maruti Swift Dzire VXI  ₹ 4.50 Lakh            2015
# 3           3   2015 Maruti Swift Dzire VXI  ₹ 4.50 Lakh            2015
# 4           4    2009 Hyundai i10 Magna 1.1  ₹ 1.60 Lakh            2009
#
#   engine_capacity              insurance transmission_type  kms_driven  \
# 0         1197 cc  Third Party insurance            Manual  40,000 Kms
# 1         2179 cc  Third Party insurance         Automatic  70,000 Kms
# 2         1197 cc  Third Party insurance            Manual  70,000 Kms
# 3         1197 cc  Third Party insurance            Manual  70,000 Kms
# 4         1086 cc  Third Party insurance            Manual  80,000 Kms
#
#      owner_type fuel_type  max_power  seats     mileage  body_type  city Brand
# ...

# %%
df1.rename(columns={"Brand": "Year"}, inplace=True)
df1.head()
# Out:
#    Unnamed: 0                     full_name resale_price registered_year  \
# 0           0  2017 Maruti Baleno 1.2 Alpha  ₹ 5.45 Lakh            2017
# 1           1            2018 Tata Hexa XTA    ₹ 10 Lakh            2018
# 2           2   2015 Maruti Swift Dzire VXI  ₹ 4.50 Lakh            2015
# 3           3   2015 Maruti Swift Dzire VXI  ₹ 4.50 Lakh            2015
# 4           4    2009 Hyundai i10 Magna 1.1  ₹ 1.60 Lakh            2009
#
#   engine_capacity              insurance transmission_type  kms_driven  \
# 0         1197 cc  Third Party insurance            Manual  40,000 Kms
# 1         2179 cc  Third Party insurance         Automatic  70,000 Kms
# 2         1197 cc  Third Party insurance            Manual  70,000 Kms
# 3         1197 cc  Third Party insurance            Manual  70,000 Kms
# 4         1086 cc  Third Party insurance            Manual  80,000 Kms
#
#      owner_type fuel_type  max_power  seats     mileage  body_type  city  Year
# ...

# %%
df1["Brand"]= df1["full_name"].str.split().str[1]
df1["Model_name"]= df1["full_name"].str.split().str[1:]
df1.head()
# Out:
#    Unnamed: 0                     full_name resale_price registered_year  \
# 0           0  2017 Maruti Baleno 1.2 Alpha  ₹ 5.45 Lakh            2017
# 1           1            2018 Tata Hexa XTA    ₹ 10 Lakh            2018
# 2           2   2015 Maruti Swift Dzire VXI  ₹ 4.50 Lakh            2015
# 3           3   2015 Maruti Swift Dzire VXI  ₹ 4.50 Lakh            2015
# 4           4    2009 Hyundai i10 Magna 1.1  ₹ 1.60 Lakh            2009
#
#   engine_capacity              insurance transmission_type  kms_driven  \
# 0         1197 cc  Third Party insurance            Manual  40,000 Kms
# 1         2179 cc  Third Party insurance         Automatic  70,000 Kms
# 2         1197 cc  Third Party insurance            Manual  70,000 Kms
# 3         1197 cc  Third Party insurance            Manual  70,000 Kms
# 4         1086 cc  Third Party insurance            Manual  80,000 Kms
#
#      owner_type fuel_type  max_power  seats     mileage  body_type  city  \
# ...

# %%
df1["Model_name"] = df1["Model_name"].str.join(" ")
df1.head()
# Out:
#    Unnamed: 0                     full_name resale_price registered_year  \
# 0           0  2017 Maruti Baleno 1.2 Alpha  ₹ 5.45 Lakh            2017
# 1           1            2018 Tata Hexa XTA    ₹ 10 Lakh            2018
# 2           2   2015 Maruti Swift Dzire VXI  ₹ 4.50 Lakh            2015
# 3           3   2015 Maruti Swift Dzire VXI  ₹ 4.50 Lakh            2015
# 4           4    2009 Hyundai i10 Magna 1.1  ₹ 1.60 Lakh            2009
#
#   engine_capacity              insurance transmission_type  kms_driven  \
# 0         1197 cc  Third Party insurance            Manual  40,000 Kms
# 1         2179 cc  Third Party insurance         Automatic  70,000 Kms
# 2         1197 cc  Third Party insurance            Manual  70,000 Kms
# 3         1197 cc  Third Party insurance            Manual  70,000 Kms
# 4         1086 cc  Third Party insurance            Manual  80,000 Kms
#
#      owner_type fuel_type  max_power  seats     mileage  body_type  city  \
# ...

# %%
df1.duplicated().sum()
# Out:
# np.int64(0)

# %%
df1.drop(columns=["Unnamed: 0", "full_name"], inplace=True)

# %%
df1.head()
# Out:
#   resale_price registered_year engine_capacity              insurance  \
# 0  ₹ 5.45 Lakh            2017         1197 cc  Third Party insurance
# 1    ₹ 10 Lakh            2018         2179 cc  Third Party insurance
# 2  ₹ 4.50 Lakh            2015         1197 cc  Third Party insurance
# 3  ₹ 4.50 Lakh            2015         1197 cc  Third Party insurance
# 4  ₹ 1.60 Lakh            2009         1086 cc  Third Party insurance
#
#   transmission_type  kms_driven    owner_type fuel_type  max_power  seats  \
# 0            Manual  40,000 Kms   First Owner    Petrol    83.1bhp    5.0
# 1         Automatic  70,000 Kms   First Owner    Diesel  153.86bhp    7.0
# 2            Manual  70,000 Kms  Second Owner    Petrol   83.14bhp    5.0
# 3            Manual  70,000 Kms  Second Owner    Petrol   83.14bhp    5.0
# 4            Manual  80,000 Kms   First Owner    Petrol   68.05bhp    5.0
#
#       mileage  body_type  city  Year    Brand               Model_name
# ...

# %%
df1.duplicated().sum()
# Out:
# np.int64(203)

# %%
df1.drop_duplicates(inplace=True)
df1.duplicated().sum()
# Out:
# np.int64(0)

# %%
df1.head()
# Out:
#   resale_price registered_year engine_capacity              insurance  \
# 0  ₹ 5.45 Lakh            2017         1197 cc  Third Party insurance
# 1    ₹ 10 Lakh            2018         2179 cc  Third Party insurance
# 2  ₹ 4.50 Lakh            2015         1197 cc  Third Party insurance
# 4  ₹ 1.60 Lakh            2009         1086 cc  Third Party insurance
# 5  ₹ 4.70 Lakh            2015         1197 cc  Third Party insurance
#
#   transmission_type  kms_driven    owner_type fuel_type  max_power  seats  \
# 0            Manual  40,000 Kms   First Owner    Petrol    83.1bhp    5.0
# 1         Automatic  70,000 Kms   First Owner    Diesel  153.86bhp    7.0
# 2            Manual  70,000 Kms  Second Owner    Petrol   83.14bhp    5.0
# 4            Manual  80,000 Kms   First Owner    Petrol   68.05bhp    5.0
# 5            Manual  70,000 Kms   First Owner    Petrol   81.86bhp    5.0
#
#       mileage  body_type  city  Year    Brand               Model_name
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17243 entries, 0 to 17445
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   resale_price       17243 non-null  object
#  1   registered_year    17175 non-null  object
#  2   engine_capacity    17230 non-null  object
#  3   insurance          17236 non-null  object
#  4   transmission_type  17243 non-null  object
#  5   kms_driven         17240 non-null  object
#  6   owner_type         17198 non-null  object
#  7   fuel_type          17243 non-null  object
#  8   max_power          17143 non-null  object
#  9   seats              17233 non-null  float64
#  10  mileage            16741 non-null  object
#  11  body_type          17243 non-null  object
#  12  city               17243 non-null  object
#  13  Year               17243 non-null  object
#  14  Brand              17243 non-null  object
#  15  Model_name         17243 non-null  object
# ...

# %%
df1.city.unique()
# Out:
# array(['Agra', 'Gurgaon', 'Lucknow', 'Delhi', 'Chandigarh', 'Bangalore',
#        'Jaipur', 'Kolkata', 'Ahmedabad', 'Chennai', 'Pune', 'Mumbai',
#        'Hyderabad'], dtype=object)

# %%
df1.head(1)
# Out:
#   resale_price registered_year engine_capacity              insurance  \
# 0  ₹ 5.45 Lakh            2017         1197 cc  Third Party insurance
#
#   transmission_type  kms_driven   owner_type fuel_type max_power  seats  \
# 0            Manual  40,000 Kms  First Owner    Petrol   83.1bhp    5.0
#
#      mileage  body_type  city  Year   Brand               Model_name
# 0  21.4 kmpl  Hatchback  Agra  2017  Maruti  Maruti Baleno 1.2 Alpha

# %%
df1["engine_power"]=df1["engine_capacity"].str.split().str[1]
df1["price"]=df1["resale_price"].str.split().str[1]
df1["driven"]=df1["kms_driven"].str.split().str[0]
df1["avg"]=df1["mileage"].str.split().str[0]

df1.head()
# Out:
#   resale_price registered_year engine_capacity              insurance  \
# 0  ₹ 5.45 Lakh            2017         1197 cc  Third Party insurance
# 1    ₹ 10 Lakh            2018         2179 cc  Third Party insurance
# 2  ₹ 4.50 Lakh            2015         1197 cc  Third Party insurance
# 4  ₹ 1.60 Lakh            2009         1086 cc  Third Party insurance
# 5  ₹ 4.70 Lakh            2015         1197 cc  Third Party insurance
#
#   transmission_type  kms_driven    owner_type fuel_type  max_power  seats  \
# 0            Manual  40,000 Kms   First Owner    Petrol    83.1bhp    5.0
# 1         Automatic  70,000 Kms   First Owner    Diesel  153.86bhp    7.0
# 2            Manual  70,000 Kms  Second Owner    Petrol   83.14bhp    5.0
# 4            Manual  80,000 Kms   First Owner    Petrol   68.05bhp    5.0
# 5            Manual  70,000 Kms   First Owner    Petrol   81.86bhp    5.0
#
#       mileage  body_type  city  Year    Brand               Model_name  \
# ...

# %%
df1["engine_size"]=df1["engine_capacity"].str.split().str[0]
df1.head()
# Out:
#   resale_price registered_year engine_capacity              insurance  \
# 0  ₹ 5.45 Lakh            2017         1197 cc  Third Party insurance
# 1    ₹ 10 Lakh            2018         2179 cc  Third Party insurance
# 2  ₹ 4.50 Lakh            2015         1197 cc  Third Party insurance
# 4  ₹ 1.60 Lakh            2009         1086 cc  Third Party insurance
# 5  ₹ 4.70 Lakh            2015         1197 cc  Third Party insurance
#
#   transmission_type  kms_driven    owner_type fuel_type  max_power  seats  \
# 0            Manual  40,000 Kms   First Owner    Petrol    83.1bhp    5.0
# 1         Automatic  70,000 Kms   First Owner    Diesel  153.86bhp    7.0
# 2            Manual  70,000 Kms  Second Owner    Petrol   83.14bhp    5.0
# 4            Manual  80,000 Kms   First Owner    Petrol   68.05bhp    5.0
# 5            Manual  70,000 Kms   First Owner    Petrol   81.86bhp    5.0
#
#    ...  body_type  city  Year    Brand               Model_name engine_power  \
# ...

# %%
df1["car_price"]=df1["resale_price"].str.split().str[1]
df1.head()
# Out:
#   resale_price registered_year engine_capacity              insurance  \
# 0  ₹ 5.45 Lakh            2017         1197 cc  Third Party insurance
# 1    ₹ 10 Lakh            2018         2179 cc  Third Party insurance
# 2  ₹ 4.50 Lakh            2015         1197 cc  Third Party insurance
# 4  ₹ 1.60 Lakh            2009         1086 cc  Third Party insurance
# 5  ₹ 4.70 Lakh            2015         1197 cc  Third Party insurance
#
#   transmission_type  kms_driven    owner_type fuel_type  max_power  seats  \
# 0            Manual  40,000 Kms   First Owner    Petrol    83.1bhp    5.0
# 1         Automatic  70,000 Kms   First Owner    Diesel  153.86bhp    7.0
# 2            Manual  70,000 Kms  Second Owner    Petrol   83.14bhp    5.0
# 4            Manual  80,000 Kms   First Owner    Petrol   68.05bhp    5.0
# 5            Manual  70,000 Kms   First Owner    Petrol   81.86bhp    5.0
#
#    ...  city  Year    Brand               Model_name engine_power price  \
# ...

# %%
df1["max_power"] = df1["max_power"].str.extract(r"([\d.]+)").astype(float)
df1.head()
# Out:
#   resale_price registered_year engine_capacity              insurance  \
# 0  ₹ 5.45 Lakh            2017         1197 cc  Third Party insurance
# 1    ₹ 10 Lakh            2018         2179 cc  Third Party insurance
# 2  ₹ 4.50 Lakh            2015         1197 cc  Third Party insurance
# 4  ₹ 1.60 Lakh            2009         1086 cc  Third Party insurance
# 5  ₹ 4.70 Lakh            2015         1197 cc  Third Party insurance
#
#   transmission_type  kms_driven    owner_type fuel_type  max_power  seats  \
# 0            Manual  40,000 Kms   First Owner    Petrol      83.10    5.0
# 1         Automatic  70,000 Kms   First Owner    Diesel     153.86    7.0
# 2            Manual  70,000 Kms  Second Owner    Petrol      83.14    5.0
# 4            Manual  80,000 Kms   First Owner    Petrol      68.05    5.0
# 5            Manual  70,000 Kms   First Owner    Petrol      81.86    5.0
#
#    ...  city  Year    Brand               Model_name engine_power price  \
# ...

# %%
df2=df1.drop(columns=["resale_price","engine_capacity","kms_driven","mileage","price"])
df2.head()
# Out:
#   registered_year              insurance transmission_type    owner_type  \
# 0            2017  Third Party insurance            Manual   First Owner
# 1            2018  Third Party insurance         Automatic   First Owner
# 2            2015  Third Party insurance            Manual  Second Owner
# 4            2009  Third Party insurance            Manual   First Owner
# 5            2015  Third Party insurance            Manual   First Owner
#
#   fuel_type  max_power  seats  body_type  city  Year    Brand  \
# 0    Petrol      83.10    5.0  Hatchback  Agra  2017   Maruti
# 1    Diesel     153.86    7.0        MUV  Agra  2018     Tata
# 2    Petrol      83.14    5.0      Sedan  Agra  2015   Maruti
# 4    Petrol      68.05    5.0  Hatchback  Agra  2009  Hyundai
# 5    Petrol      81.86    5.0  Hatchback  Agra  2015  Hyundai
#
#                 Model_name engine_power  driven    avg engine_size car_price
# ...

# %%
df2=df2.drop(columns=["engine_power"])
df2.head()
# Out:
#   registered_year              insurance transmission_type    owner_type  \
# 0            2017  Third Party insurance            Manual   First Owner
# 1            2018  Third Party insurance         Automatic   First Owner
# 2            2015  Third Party insurance            Manual  Second Owner
# 4            2009  Third Party insurance            Manual   First Owner
# 5            2015  Third Party insurance            Manual   First Owner
#
#   fuel_type  max_power  seats  body_type  city  Year    Brand  \
# 0    Petrol      83.10    5.0  Hatchback  Agra  2017   Maruti
# 1    Diesel     153.86    7.0        MUV  Agra  2018     Tata
# 2    Petrol      83.14    5.0      Sedan  Agra  2015   Maruti
# 4    Petrol      68.05    5.0  Hatchback  Agra  2009  Hyundai
# 5    Petrol      81.86    5.0  Hatchback  Agra  2015  Hyundai
#
#                 Model_name  driven    avg engine_size car_price
# 0  Maruti Baleno 1.2 Alpha  40,000   21.4        1197      5.45
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17243 entries, 0 to 17445
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   registered_year    17175 non-null  object
#  1   insurance          17236 non-null  object
#  2   transmission_type  17243 non-null  object
#  3   owner_type         17198 non-null  object
#  4   fuel_type          17243 non-null  object
#  5   max_power          17143 non-null  float64
#  6   seats              17233 non-null  float64
#  7   body_type          17243 non-null  object
#  8   city               17243 non-null  object
#  9   Year               17243 non-null  object
#  10  Brand              17243 non-null  object
#  11  Model_name         17243 non-null  object
#  12  driven             17240 non-null  object
#  13  avg                16741 non-null  object
#  14  engine_size        17230 non-null  object
#  15  car_price          17243 non-null  object
# ...

# %%
df3 = df2.copy()

# %%
df2["registered_year"].isnull().sum()
# Out:
# np.int64(68)

# %%
df2.dropna(subset=["registered_year"], inplace=True)

# %%
df2["registered_year"].isnull().sum()
# Out:
# np.int64(0)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17175 entries, 0 to 17445
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   registered_year    17175 non-null  object
#  1   insurance          17168 non-null  object
#  2   transmission_type  17175 non-null  object
#  3   owner_type         17175 non-null  object
#  4   fuel_type          17175 non-null  object
#  5   max_power          17083 non-null  float64
#  6   seats              17165 non-null  float64
#  7   body_type          17175 non-null  object
#  8   city               17175 non-null  object
#  9   Year               17175 non-null  object
#  10  Brand              17175 non-null  object
#  11  Model_name         17175 non-null  object
#  12  driven             17172 non-null  object
#  13  avg                16684 non-null  object
#  14  engine_size        17165 non-null  object
#  15  car_price          17175 non-null  object
# ...

# %%
df2["insurance"].isnull().sum()
# Out:
# np.int64(7)

# %%
df2.dropna(subset=["insurance"], inplace=True)

# %%
df2["max_power"].isnull().sum()
# Out:
# np.int64(92)

# %%
df2.dropna(subset=["max_power"], inplace=True)

# %%
df2["seats"].isnull().sum()
# Out:
# np.int64(2)

# %%
df2["avg"].isnull().sum()
# Out:
# np.int64(470)

# %%
df2["engine_size"].isnull().sum()
# Out:
# np.int64(8)

# %%
df2.dropna(subset=["engine_size"], inplace=True)
df2.dropna(subset=["seats"], inplace=True)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17066 entries, 0 to 17445
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   registered_year    17066 non-null  object
#  1   insurance          17066 non-null  object
#  2   transmission_type  17066 non-null  object
#  3   owner_type         17066 non-null  object
#  4   fuel_type          17066 non-null  object
#  5   max_power          17066 non-null  float64
#  6   seats              17066 non-null  float64
#  7   body_type          17066 non-null  object
#  8   city               17066 non-null  object
#  9   Year               17066 non-null  object
#  10  Brand              17066 non-null  object
#  11  Model_name         17066 non-null  object
#  12  driven             17063 non-null  object
#  13  avg                16601 non-null  object
#  14  engine_size        17066 non-null  object
#  15  car_price          17066 non-null  object
# ...

# %%
df2.head()
# Out:
#   registered_year              insurance transmission_type    owner_type  \
# 0            2017  Third Party insurance            Manual   First Owner
# 1            2018  Third Party insurance         Automatic   First Owner
# 2            2015  Third Party insurance            Manual  Second Owner
# 4            2009  Third Party insurance            Manual   First Owner
# 5            2015  Third Party insurance            Manual   First Owner
#
#   fuel_type  max_power  seats  body_type  city  Year    Brand  \
# 0    Petrol      83.10    5.0  Hatchback  Agra  2017   Maruti
# 1    Diesel     153.86    7.0        MUV  Agra  2018     Tata
# 2    Petrol      83.14    5.0      Sedan  Agra  2015   Maruti
# 4    Petrol      68.05    5.0  Hatchback  Agra  2009  Hyundai
# 5    Petrol      81.86    5.0  Hatchback  Agra  2015  Hyundai
#
#                 Model_name  driven    avg engine_size car_price
# 0  Maruti Baleno 1.2 Alpha  40,000   21.4        1197      5.45
# ...

# %%
df2.dropna(subset=["driven"], inplace=True)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17063 entries, 0 to 17445
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   registered_year    17063 non-null  object
#  1   insurance          17063 non-null  object
#  2   transmission_type  17063 non-null  object
#  3   owner_type         17063 non-null  object
#  4   fuel_type          17063 non-null  object
#  5   max_power          17063 non-null  float64
#  6   seats              17063 non-null  float64
#  7   body_type          17063 non-null  object
#  8   city               17063 non-null  object
#  9   Year               17063 non-null  object
#  10  Brand              17063 non-null  object
#  11  Model_name         17063 non-null  object
#  12  driven             17063 non-null  object
#  13  avg                16598 non-null  object
#  14  engine_size        17063 non-null  object
#  15  car_price          17063 non-null  object
# ...

# %%
df2["avg"] = df2["avg"].astype(float)

# %%
df2["avg"] = df2["avg"].fillna(df2["avg"].mean())

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17063 entries, 0 to 17445
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   registered_year    17063 non-null  object
#  1   insurance          17063 non-null  object
#  2   transmission_type  17063 non-null  object
#  3   owner_type         17063 non-null  object
#  4   fuel_type          17063 non-null  object
#  5   max_power          17063 non-null  float64
#  6   seats              17063 non-null  float64
#  7   body_type          17063 non-null  object
#  8   city               17063 non-null  object
#  9   Year               17063 non-null  object
#  10  Brand              17063 non-null  object
#  11  Model_name         17063 non-null  object
#  12  driven             17063 non-null  object
#  13  avg                17063 non-null  float64
#  14  engine_size        17063 non-null  object
#  15  car_price          17063 non-null  object
# ...

# %%
df2["registered_year"].unique()
# Out:
# array(['2017', '2018', '2015', '2009', '2010', '2016', '2014', '2020',
#        '2021', '2019', '2011', '2012', '2013', '2022', '2004', 'Jul 2021',
#        'Dec 2018', 'Jun 2018', 'Mar 2016', 'Feb 2018', 'Oct 2014',
#        'Mar 2014', 'Feb 2013', 'Aug 2018', 'Jun 2019', 'Dec 2021',
#        'Apr 2019', 'May 2018', 'Nov 2013', 'Sept 2022', 'Jan 2021',
#        'Sept 2020', 'Jan 2015', 'Oct 2017', 'Sept 2019', 'Jul 2019',
#        'Mar 2020', 'Jan 2018', 'Nov 2015', 'May 2015', 'Dec 2014',
#        'Feb 2019', 'May 2016', 'Apr 2018', 'May 2021', '2008', 'Mar 2022',
#        'Jun 2016', 'Jul 2020', 'Jun 2017', 'Jul 2016', 'Jun 2015',
#        'Sept 2018', 'Nov 2018', 'Aug 2019', 'Jun 2021', '2006',
#        'Jan 2017', 'Aug 2014', 'Jul 2013', 'Jul 2017', 'Dec 2013',
#        'Sept 2016', 'Mar 2017', 'Feb 2020', 'Oct 2018', 'Jul 2022',
#        'May 2014', 'Aug 2021', 'Aug 2020', 'Mar 2019', 'Jan 2016',
#        'Feb 2016', 'Oct 2015', 'May 2019', 'Dec 2012', 'Nov 2021',
# ...

# %%
df2["registered_year"] = df2["registered_year"].str.extract(r"(\d{4})").astype(int)

# %%
df2["registered_year"].unique()
# Out:
# array([2017, 2018, 2015, 2009, 2010, 2016, 2014, 2020, 2021, 2019, 2011,
#        2012, 2013, 2022, 2004, 2008, 2006, 2023, 2003, 2007, 2002, 2005])

# %%
df2.head()
# Out:
#    registered_year              insurance transmission_type    owner_type  \
# 0             2017  Third Party insurance            Manual   First Owner
# 1             2018  Third Party insurance         Automatic   First Owner
# 2             2015  Third Party insurance            Manual  Second Owner
# 4             2009  Third Party insurance            Manual   First Owner
# 5             2015  Third Party insurance            Manual   First Owner
#
#   fuel_type  max_power  seats  body_type  city  Year    Brand  \
# 0    Petrol      83.10    5.0  Hatchback  Agra  2017   Maruti
# 1    Diesel     153.86    7.0        MUV  Agra  2018     Tata
# 2    Petrol      83.14    5.0      Sedan  Agra  2015   Maruti
# 4    Petrol      68.05    5.0  Hatchback  Agra  2009  Hyundai
# 5    Petrol      81.86    5.0  Hatchback  Agra  2015  Hyundai
#
#                 Model_name  driven    avg engine_size car_price
# 0  Maruti Baleno 1.2 Alpha  40,000  21.40        1197      5.45
# ...

# %%
df2["driven"] = (df2["driven"].str.replace(",", "", regex=False))
df2["driven"].unique()
# Out:
# array(['40000', '70000', '80000', ..., '120178', '800', '67634'],
#       shape=(8239,), dtype=object)

# %%
df2.head()
# Out:
#    registered_year              insurance transmission_type    owner_type  \
# 0             2017  Third Party insurance            Manual   First Owner
# 1             2018  Third Party insurance         Automatic   First Owner
# 2             2015  Third Party insurance            Manual  Second Owner
# 4             2009  Third Party insurance            Manual   First Owner
# 5             2015  Third Party insurance            Manual   First Owner
#
#   fuel_type  max_power  seats  body_type  city  Year    Brand  \
# 0    Petrol      83.10    5.0  Hatchback  Agra  2017   Maruti
# 1    Diesel     153.86    7.0        MUV  Agra  2018     Tata
# 2    Petrol      83.14    5.0      Sedan  Agra  2015   Maruti
# 4    Petrol      68.05    5.0  Hatchback  Agra  2009  Hyundai
# 5    Petrol      81.86    5.0  Hatchback  Agra  2015  Hyundai
#
#                 Model_name driven    avg engine_size car_price
# 0  Maruti Baleno 1.2 Alpha  40000  21.40        1197      5.45
# ...

# %%
df2["car_price"]=df2["car_price"].str.replace(",","",regex=False)

# %%
df2 = df2.astype({
    "registered_year": int,
    "driven": int,
    "avg": float,
    "engine_size": int,
    "car_price": float
})

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17063 entries, 0 to 17445
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   registered_year    17063 non-null  int64
#  1   insurance          17063 non-null  object
#  2   transmission_type  17063 non-null  object
#  3   owner_type         17063 non-null  object
#  4   fuel_type          17063 non-null  object
#  5   max_power          17063 non-null  float64
#  6   seats              17063 non-null  float64
#  7   body_type          17063 non-null  object
#  8   city               17063 non-null  object
#  9   Year               17063 non-null  object
#  10  Brand              17063 non-null  object
#  11  Model_name         17063 non-null  object
#  12  driven             17063 non-null  int64
#  13  avg                17063 non-null  float64
#  14  engine_size        17063 non-null  int64
#  15  car_price          17063 non-null  float64
# ...

# %%
df2.head()
# Out:
#    registered_year              insurance transmission_type    owner_type  \
# 0             2017  Third Party insurance            Manual   First Owner
# 1             2018  Third Party insurance         Automatic   First Owner
# 2             2015  Third Party insurance            Manual  Second Owner
# 4             2009  Third Party insurance            Manual   First Owner
# 5             2015  Third Party insurance            Manual   First Owner
#
#   fuel_type  max_power  seats  body_type  city  Year    Brand  \
# 0    Petrol      83.10    5.0  Hatchback  Agra  2017   Maruti
# 1    Diesel     153.86    7.0        MUV  Agra  2018     Tata
# 2    Petrol      83.14    5.0      Sedan  Agra  2015   Maruti
# 4    Petrol      68.05    5.0  Hatchback  Agra  2009  Hyundai
# 5    Petrol      81.86    5.0  Hatchback  Agra  2015  Hyundai
#
#                 Model_name  driven    avg  engine_size  car_price
# 0  Maruti Baleno 1.2 Alpha   40000  21.40         1197       5.45
# ...

# %%
df2.describe()
# Out:
#        registered_year     max_power         seats        driven  \
# count     17063.000000  17063.000000  17063.000000  1.706300e+04
# mean       2016.460704    103.909736      5.204829  5.847677e+04
# std           3.611442     44.675940      0.664642  6.466758e+04
# min        2002.000000     25.500000      2.000000  2.860000e+02
# 25%        2014.000000     78.900000      5.000000  3.200000e+04
# 50%        2017.000000     88.500000      5.000000  5.461400e+04
# 75%        2019.000000    118.350000      5.000000  7.904800e+04
# max        2023.000000    558.000000     14.000000  6.275000e+06
#
#                 avg   engine_size     car_price
# count  17063.000000  17063.000000  17063.000000
# mean      19.393051   1424.019575    739.516574
# std        4.093524    474.063727   7488.128707
# min        6.700000      0.000000      1.000000
# 25%       17.010000   1197.000000      3.900000
# 50%       19.020000   1248.000000      5.950000
# ...

# %%
df3=df2.copy()

# %%
df2["car_price"].unique()
# Out:
# array([ 5.45, 10.  ,  4.5 , ..., 62.9 , 26.89, 11.29], shape=(1711,))

# %%
df2["car_price"].drop_duplicates().sort_values(ascending=True)
# Out:
# 24           1.00
# 1421         1.01
# 10000        1.03
# 544          1.05
# 745          1.06
#            ...
# 3090     96107.00
# 6757     98000.00
# 1243     98657.00
# 886      99000.00
# 3073     99999.00
# Name: car_price, Length: 1711, dtype: float64

# %%
df2["car_price"].drop_duplicates().sort_values(ascending=False).head(10)
# Out:
# 3073    99999.0
# 886     99000.0
# 1243    98657.0
# 6757    98000.0
# 3090    96107.0
# 9794    96090.0
# 1623    95000.0
# 9873    94231.0
# 9685    92293.0
# 9849    92000.0
# Name: car_price, dtype: float64

# %%
def fix_values(x):
    if x<100:
        return x*100
    else : 
        return x
df2["car_price"]=df2["car_price"].apply(fix_values)

# %%
df2.describe()
# Out:
#        registered_year     max_power         seats        driven  \
# count     17063.000000  17063.000000  17063.000000  1.706300e+04
# mean       2016.460704    103.909736      5.204829  5.847677e+04
# std           3.611442     44.675940      0.664642  6.466758e+04
# min        2002.000000     25.500000      2.000000  2.860000e+02
# 25%        2014.000000     78.900000      5.000000  3.200000e+04
# 50%        2017.000000     88.500000      5.000000  5.461400e+04
# 75%        2019.000000    118.350000      5.000000  7.904800e+04
# max        2023.000000    558.000000     14.000000  6.275000e+06
#
#                 avg   engine_size     car_price
# count  17063.000000  17063.000000  17063.000000
# mean      19.393051   1424.019575   1594.986755
# std        4.093524    474.063727   7466.911738
# min        6.700000      0.000000    100.000000
# 25%       17.010000   1197.000000    390.000000
# 50%       19.020000   1248.000000    595.000000
# ...

# %%
df2.loc[df2["car_price"] == 99999.00]
# Out:
#        registered_year              insurance transmission_type    owner_type  \
# 3073              2008  Third Party insurance            Manual   First Owner
# 3432              2010  Third Party insurance            Manual   First Owner
# 15269             2008  Third Party insurance            Manual  Second Owner
#
#       fuel_type  max_power  seats  body_type     city  Year   Brand  \
# 3073     Petrol       67.0    5.0  Hatchback  Kolkata  2008  Maruti
# 3432     Diesel       73.9    5.0  Hatchback  Kolkata  2010  Maruti
# 15269    Petrol       67.1    5.0  Hatchback    Delhi  2008  Maruti
#
#                      Model_name  driven   avg  engine_size  car_price
# 3073   Maruti Wagon R LXI Minor   40000  18.9         1061    99999.0
# 3432        Maruti Ritz VDi ABS   70000  21.1         1248    99999.0
# 15269  Maruti Wagon R VXI Minor   50000  18.9          998    99999.0

# %%
df1["resale_price"].unique()
# Out:
# array(['₹ 5.45 Lakh', '₹ 10 Lakh', '₹ 4.50 Lakh', ..., '₹ 62.90 Lakh',
#        '₹ 26.89 Lakh', '₹ 11.29 Lakh'], shape=(1738,), dtype=object)

# %%
df2["resale_price"] = df1["resale_price"]

# %%
df2.head()
# Out:
#    registered_year              insurance transmission_type    owner_type  \
# 0             2017  Third Party insurance            Manual   First Owner
# 1             2018  Third Party insurance         Automatic   First Owner
# 2             2015  Third Party insurance            Manual  Second Owner
# 4             2009  Third Party insurance            Manual   First Owner
# 5             2015  Third Party insurance            Manual   First Owner
#
#   fuel_type  max_power  seats  body_type  city  Year    Brand  \
# 0    Petrol      83.10    5.0  Hatchback  Agra  2017   Maruti
# 1    Diesel     153.86    7.0        MUV  Agra  2018     Tata
# 2    Petrol      83.14    5.0      Sedan  Agra  2015   Maruti
# 4    Petrol      68.05    5.0  Hatchback  Agra  2009  Hyundai
# 5    Petrol      81.86    5.0  Hatchback  Agra  2015  Hyundai
#
#                 Model_name  driven    avg  engine_size  car_price resale_price
# ...

# %%
df3=df2.copy()

# %%
df2["resale_price"]=df2["resale_price"].str[1:]
df2.head()
# Out:
#    registered_year              insurance transmission_type    owner_type  \
# 0             2017  Third Party insurance            Manual   First Owner
# 1             2018  Third Party insurance         Automatic   First Owner
# 2             2015  Third Party insurance            Manual  Second Owner
# 4             2009  Third Party insurance            Manual   First Owner
# 5             2015  Third Party insurance            Manual   First Owner
#
#   fuel_type  max_power  seats  body_type  city  Year    Brand  \
# 0    Petrol      83.10    5.0  Hatchback  Agra  2017   Maruti
# 1    Diesel     153.86    7.0        MUV  Agra  2018     Tata
# 2    Petrol      83.14    5.0      Sedan  Agra  2015   Maruti
# 4    Petrol      68.05    5.0  Hatchback  Agra  2009  Hyundai
# 5    Petrol      81.86    5.0  Hatchback  Agra  2015  Hyundai
#
#                 Model_name  driven    avg  engine_size  car_price resale_price
# ...

# %%
df2["resale_price"].tolist()
# Out:
# [' 5.45 Lakh',
#  ' 10 Lakh',
#  ' 4.50 Lakh',
#  ' 1.60 Lakh',
#  ' 4.70 Lakh',
#  ' 3.60 Lakh',
#  ' 2 Lakh',
#  ' 3.70 Lakh',
#  ' 1.20 Lakh',
#  ' 3.30 Lakh',
#  ' 4.75 Lakh',
#  ' 6.86 Lakh',
#  ' 12.50 Lakh',
#  ' 11 Lakh',
#  ' 3.95 Lakh',
#  ' 3.50 Lakh',
#  ' 2.89 Lakh',
#  ' 2.82 Lakh',
#  ' 10 Lakh',
#  ' 7.85 Lakh',
#  ' 3 Lakh',
#  ' 3.97 Lakh',
#  ' 3.75 Lakh',
#  ' 1 Lakh',
#  ' 6.75 Lakh',
#  ' 4.65 Lakh',
#  ' 4.80 Lakh',
#  ' 2.25 Lakh',
#  ' 3.20 Lakh',
#  ' 4.15 Lakh',
#  ' 2.40 Lakh',
#  ' 3.50 Lakh',
#  ' 2.96 Lakh',
#  ' 3.16 Lakh',
#  ' 7.50 Lakh',
#  ' 9 Lakh',
#  ' 5.60 Lakh',
#  ' 8 Lakh',
#  ' 9 Lakh',
#  ' 2.80 Lakh',
#  ' 5.50 Lakh',
#  ' 2.50 Lakh',
#  ' 1.50 Lakh',
#  ' 4.80 Lakh',
#  ' 3 Lakh',
#  ' 12 Lakh',
#  ' 8 Lakh',
#  ' 2 Lakh',
#  ' 7.40 Lakh',
#  ' 1.50 Lakh',
#  ' 5.20 Lakh',
#  ' 1.70 Lakh',
#  ' 7.10 Lakh',
#  ' 9.50 Lakh',
#  ' 2.40 Lakh',
#  ' 9.30 Lakh',
#  ' 19.22 Lakh',
#  ' 1.50 Lakh',
#  ' 3.80 Lakh',
#  ' 5.90 Lakh',
# ...

# %%
def convert_price(x):
    x = str(x).strip().replace(",", "")

    if "Lakh" in x:
        num = float(x.replace("Lakh", "").strip())
        return num * 100000

    elif "Crore" in x:
        num = float(x.replace("Crore", "").strip())
        return num * 10000000

    else:
        return float(x)

# %%
df2["resale_price"] = df2["resale_price"].apply(convert_price)

# %%
df2.describe()
# Out:
#        registered_year     max_power         seats        driven  \
# count     17063.000000  17063.000000  17063.000000  1.706300e+04
# mean       2016.460704    103.909736      5.204829  5.847677e+04
# std           3.611442     44.675940      0.664642  6.466758e+04
# min        2002.000000     25.500000      2.000000  2.860000e+02
# 25%        2014.000000     78.900000      5.000000  3.200000e+04
# 50%        2017.000000     88.500000      5.000000  5.461400e+04
# 75%        2019.000000    118.350000      5.000000  7.904800e+04
# max        2023.000000    558.000000     14.000000  6.275000e+06
#
#                 avg   engine_size     car_price  resale_price
# count  17063.000000  17063.000000  17063.000000  1.706300e+04
# mean      19.393051   1424.019575   1594.986755  8.854858e+05
# std        4.093524    474.063727   7466.911738  1.087753e+06
# min        6.700000      0.000000    100.000000  2.800000e+04
# 25%       17.010000   1197.000000    390.000000  3.830000e+05
# ...

# %%
df2.head()
# Out:
#    registered_year              insurance transmission_type    owner_type  \
# 0             2017  Third Party insurance            Manual   First Owner
# 1             2018  Third Party insurance         Automatic   First Owner
# 2             2015  Third Party insurance            Manual  Second Owner
# 4             2009  Third Party insurance            Manual   First Owner
# 5             2015  Third Party insurance            Manual   First Owner
#
#   fuel_type  max_power  seats  body_type  city  Year    Brand  \
# 0    Petrol      83.10    5.0  Hatchback  Agra  2017   Maruti
# 1    Diesel     153.86    7.0        MUV  Agra  2018     Tata
# 2    Petrol      83.14    5.0      Sedan  Agra  2015   Maruti
# 4    Petrol      68.05    5.0  Hatchback  Agra  2009  Hyundai
# 5    Petrol      81.86    5.0  Hatchback  Agra  2015  Hyundai
#
#                 Model_name  driven    avg  engine_size  car_price  \
# 0  Maruti Baleno 1.2 Alpha   40000  21.40         1197      545.0
# ...

# %%
df2.describe()
# Out:
#        registered_year     max_power         seats        driven  \
# count     17063.000000  17063.000000  17063.000000  1.706300e+04
# mean       2016.460704    103.909736      5.204829  5.847677e+04
# std           3.611442     44.675940      0.664642  6.466758e+04
# min        2002.000000     25.500000      2.000000  2.860000e+02
# 25%        2014.000000     78.900000      5.000000  3.200000e+04
# 50%        2017.000000     88.500000      5.000000  5.461400e+04
# 75%        2019.000000    118.350000      5.000000  7.904800e+04
# max        2023.000000    558.000000     14.000000  6.275000e+06
#
#                 avg   engine_size     car_price  resale_price
# count  17063.000000  17063.000000  17063.000000  1.706300e+04
# mean      19.393051   1424.019575   1594.986755  8.854858e+05
# std        4.093524    474.063727   7466.911738  1.087753e+06
# min        6.700000      0.000000    100.000000  2.800000e+04
# 25%       17.010000   1197.000000    390.000000  3.830000e+05
# ...

# %%
df2['resale_price'].nlargest(10)
# Out:
# 1476     22500000.0
# 1505     18000000.0
# 16265    16600000.0
# 1477     15700000.0
# 17389    15700000.0
# 15461    15500000.0
# 16102    15500000.0
# 16435    15500000.0
# 7179     13000000.0
# 10525    13000000.0
# Name: resale_price, dtype: float64

# %%
df2.sort_values(by='resale_price', ascending=True).head(10)
# Out:
#        registered_year              insurance transmission_type    owner_type  \
# 2508              2007  Third Party insurance            Manual  Second Owner
# 2091              2003          Not Available            Manual  Second Owner
# 2092              2003          Not Available            Manual  Fourth Owner
# 4264              2011  Third Party insurance            Manual  Second Owner
# 9793              2008          Not Available            Manual   Third Owner
# 16618             2007  Third Party insurance            Manual  Second Owner
# 1923              2004  Third Party insurance            Manual   First Owner
# 3856              2004  Third Party insurance            Manual  Fourth Owner
# 2520              2005  Third Party insurance            Manual   First Owner
# 2439              2004  Third Party insurance            Manual  Fourth Owner
#
#       fuel_type  max_power  seats  body_type       city  Year   Brand  \
# ...

# %%
df2.drop('car_price', axis=1, inplace=True)
df2.head()
# Out:
#    registered_year              insurance transmission_type    owner_type  \
# 0             2017  Third Party insurance            Manual   First Owner
# 1             2018  Third Party insurance         Automatic   First Owner
# 2             2015  Third Party insurance            Manual  Second Owner
# 4             2009  Third Party insurance            Manual   First Owner
# 5             2015  Third Party insurance            Manual   First Owner
#
#   fuel_type  max_power  seats  body_type  city  Year    Brand  \
# 0    Petrol      83.10    5.0  Hatchback  Agra  2017   Maruti
# 1    Diesel     153.86    7.0        MUV  Agra  2018     Tata
# 2    Petrol      83.14    5.0      Sedan  Agra  2015   Maruti
# 4    Petrol      68.05    5.0  Hatchback  Agra  2009  Hyundai
# 5    Petrol      81.86    5.0  Hatchback  Agra  2015  Hyundai
#
#                 Model_name  driven    avg  engine_size  resale_price
# 0  Maruti Baleno 1.2 Alpha   40000  21.40         1197      545000.0
# ...

# %%
df2.nunique()
# Out:
# registered_year        22
# insurance               7
# transmission_type       2
# owner_type              5
# fuel_type               5
# max_power             517
# seats                   9
# body_type              26
# city                   13
# Year                   22
# Brand                  33
# Model_name           3334
# driven               8239
# avg                   580
# engine_size           153
# resale_price         1723
# dtype: int64

# %%
df2.head()
# Out:
#    registered_year              insurance transmission_type    owner_type  \
# 0             2017  Third Party insurance            Manual   First Owner
# 1             2018  Third Party insurance         Automatic   First Owner
# 2             2015  Third Party insurance            Manual  Second Owner
# 4             2009  Third Party insurance            Manual   First Owner
# 5             2015  Third Party insurance            Manual   First Owner
#
#   fuel_type  max_power  seats  body_type  city  Year    Brand  \
# 0    Petrol      83.10    5.0  Hatchback  Agra  2017   Maruti
# 1    Diesel     153.86    7.0        MUV  Agra  2018     Tata
# 2    Petrol      83.14    5.0      Sedan  Agra  2015   Maruti
# 4    Petrol      68.05    5.0  Hatchback  Agra  2009  Hyundai
# 5    Petrol      81.86    5.0  Hatchback  Agra  2015  Hyundai
#
#                 Model_name  driven    avg  engine_size  resale_price
# 0  Maruti Baleno 1.2 Alpha   40000  21.40         1197      545000.0
# ...

# %%
df3=df2.copy()

# %%
categorical_cols = ['insurance', 'transmission_type', 'owner_type', 'fuel_type','body_type','city','Brand']

df3 = pd.get_dummies(
    df3,
    columns=categorical_cols,
    drop_first=True,
    dtype=int
)

# %%
df3.head()
# Out:
#    registered_year  max_power  seats  Year               Model_name  driven  \
# 0             2017      83.10    5.0  2017  Maruti Baleno 1.2 Alpha   40000
# 1             2018     153.86    7.0  2018            Tata Hexa XTA   70000
# 2             2015      83.14    5.0  2015   Maruti Swift Dzire VXI   70000
# 4             2009      68.05    5.0  2009    Hyundai i10 Magna 1.1   80000
# 5             2015      81.86    5.0  2015   Hyundai i20 Active 1.2   70000
#
#      avg  engine_size  resale_price  insurance_2  ...  Brand_Mitsubishi  \
# 0  21.40         1197      545000.0            0  ...                 0
# 1  17.60         2179     1000000.0            0  ...                 0
# 2  20.85         1197      450000.0            0  ...                 0
# 4  19.81         1086      160000.0            0  ...                 0
# 5  17.19         1197      470000.0            0  ...                 0
#
# ...

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17063 entries, 0 to 17445
# Data columns (total 93 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   registered_year                  17063 non-null  int64
#  1   max_power                        17063 non-null  float64
#  2   seats                            17063 non-null  float64
#  3   Year                             17063 non-null  object
#  4   Model_name                       17063 non-null  object
#  5   driven                           17063 non-null  int64
#  6   avg                              17063 non-null  float64
#  7   engine_size                      17063 non-null  int64
#  8   resale_price                     17063 non-null  float64
#  9   insurance_2                      17063 non-null  int64
#  10  insurance_Comprehensive          17063 non-null  int64
#  11  insurance_Not Available          17063 non-null  int64
# ...

# %%
df3["Year"]=df3["Year"].astype(int)

# %%
df2["body_type"].unique()
# Out:
# array(['Hatchback', 'MUV', 'Sedan', 'Minivans', 'SUV', 'Toyota', 'Coupe',
#        'Chevrolet', 'Mercedes-Benz', 'Audi', 'Maruti', 'Pickup',
#        'Porsche', 'Tata', 'Mahindra', 'Volvo', 'Jaguar', 'BMW', 'Cars',
#        'Datsun', 'Hyundai', 'Honda', 'Convertibles', 'Wagon', 'Skoda',
#        'Isuzu'], dtype=object)

# %%
'body_type_Toyota','body_type_Chevrolet', 'body_type_Mercedes-Benz', 'body_type_Audi', 'body_type_Maruti','body_type_Porsche', 'body_type_Tata', 'body_type_Mahindra', 
'body_type_Volvo', 'body_type_Jaguar', 'body_type_BMW', 'body_type_Cars',
'body_type_Datsun', 'body_type_Hyundai', 'body_type_Honda','body_type_Skoda','body_type_Isuzu'
# Out:
# ('body_type_Datsun',
#  'body_type_Hyundai',
#  'body_type_Honda',
#  'body_type_Skoda',
#  'body_type_Isuzu')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17243 entries, 0 to 17445
# Data columns (total 22 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   resale_price       17243 non-null  object
#  1   registered_year    17175 non-null  object
#  2   engine_capacity    17230 non-null  object
#  3   insurance          17236 non-null  object
#  4   transmission_type  17243 non-null  object
#  5   kms_driven         17240 non-null  object
#  6   owner_type         17198 non-null  object
#  7   fuel_type          17243 non-null  object
#  8   max_power          17143 non-null  float64
#  9   seats              17233 non-null  float64
#  10  mileage            16741 non-null  object
#  11  body_type          17243 non-null  object
#  12  city               17243 non-null  object
#  13  Year               17243 non-null  object
#  14  Brand              17243 non-null  object
#  15  Model_name         17243 non-null  object
# ...

# %%
df1["body_type"].value_counts()
# Out:
# body_type
# Hatchback        7269
# Sedan            4736
# SUV              4347
# MUV               744
# Minivans           56
# Maruti             19
# Pickup             13
# Coupe              10
# Cars                8
# Tata                7
# Mercedes-Benz       6
# Mahindra            4
# Chevrolet           3
# Jaguar              3
# BMW                 2
# Toyota              2
# Datsun              2
# Honda               2
# Convertibles        2
# Wagon               2
# Audi                1
# Porsche             1
# Volvo               1
# Hyundai             1
# Skoda               1
# Isuzu               1
# Name: count, dtype: int64

# %%
df3.drop(columns=['body_type_Toyota','body_type_Chevrolet', 'body_type_Mercedes-Benz','body_type_Maruti','body_type_Porsche', 'body_type_Tata', 'body_type_Mahindra', 
'body_type_Volvo', 'body_type_Jaguar', 'body_type_BMW', 'body_type_Cars',
'body_type_Datsun', 'body_type_Hyundai', 'body_type_Honda','body_type_Skoda','body_type_Isuzu'],inplace=True)

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17063 entries, 0 to 17445
# Data columns (total 77 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   registered_year                  17063 non-null  int64
#  1   max_power                        17063 non-null  float64
#  2   seats                            17063 non-null  float64
#  3   Year                             17063 non-null  int64
#  4   Model_name                       17063 non-null  object
#  5   driven                           17063 non-null  int64
#  6   avg                              17063 non-null  float64
#  7   engine_size                      17063 non-null  int64
#  8   resale_price                     17063 non-null  float64
#  9   insurance_2                      17063 non-null  int64
#  10  insurance_Comprehensive          17063 non-null  int64
#  11  insurance_Not Available          17063 non-null  int64
# ...

# %%
y=df3["resale_price"]
x=df3.drop(columns=["resale_price","Model_name"])

# %%
y.info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 17063 entries, 0 to 17445
# Series name: resale_price
# Non-Null Count  Dtype
# --------------  -----
# 17063 non-null  float64
# dtypes: float64(1)
# memory usage: 782.6 KB

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=42)

# %%
lr=LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
dt = DecisionTreeRegressor(random_state=42)

dt_params = {

    'criterion': ['squared_error', 'friedman_mse'],

    'max_depth': [5, 10, 15, 20, None],

    'min_samples_split': [2, 5, 10],

    'min_samples_leaf': [1, 2, 4]

}

grid_dt = GridSearchCV(

    estimator=dt,

    param_grid=dt_params,

    cv=5,

    scoring='r2',

    n_jobs=-1

)

grid_dt.fit(x_train, y_train)

# Random Forest Hyperparameter Tuning


rf = RandomForestRegressor(random_state=42)

rf_params = {

    'n_estimators': [100,],

    'max_depth': [10, 20,],

    'min_samples_split': [2, 5, 10],

    'min_samples_leaf': [1, 2, 4],

    'max_features': ['sqrt', 'log2']

}

grid_rf = GridSearchCV(

    estimator=rf,

    param_grid=rf_params,

    cv=5,

    scoring='r2',

    n_jobs=-1

)

grid_rf.fit(x_train, y_train)

# Best Models


best_dt = grid_dt.best_estimator_

best_rf = grid_rf.best_estimator_

print("Best Decision Tree Parameters:")

print(grid_dt.best_params_)

print("\nBest Random Forest Parameters:")

print(grid_rf.best_params_)
# Out:
# Best Decision Tree Parameters:
# {'criterion': 'squared_error', 'max_depth': None, 'min_samples_leaf': 2, 'min_samples_split': 10}
#
# Best Random Forest Parameters:
# {'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100}

# %%
# Linear Regression
lr_pred = lr.predict(x_test)

# Tuned Decision Tree
dt_pred = best_dt.predict(x_test)

# Tuned Random Forest
rf_pred = best_rf.predict(x_test)

# %%
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
import numpy as np
models = {
    "Linear Regression": lr_pred,
    "Decision Tree (Tuned)": dt_pred,
    "Random Forest (Tuned)": rf_pred
}
for name, pred in models.items():
    print(f"\n{name}")
    print("R2 Score :", r2_score(y_test, pred))
    print("MAE      :", mean_absolute_error(y_test, pred))
    print("RMSE     :", np.sqrt(mean_squared_error(y_test, pred)))
# Out:
# Linear Regression
# R2 Score : 0.6960584539026662
# MAE      : 282495.18766650924
# RMSE     : 596148.8755690665
#
# Decision Tree (Tuned)
# R2 Score : 0.8602452111385879
# MAE      : 144176.77021972297
# RMSE     : 404243.4988486492
#
# Random Forest (Tuned)
# R2 Score : 0.8822762979949084
# MAE      : 117871.97802892241
# RMSE     : 371015.1554834509

# %%
import joblib

joblib.dump(best_rf, "car_price_random_forest.pkl", compress=3)
# Out:
# ['car_price_random_forest.pkl']
